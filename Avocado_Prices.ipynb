# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("avocado.csv")
df
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.isnull().sum()#no null values
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.hist(bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff18589bc18>,
# ...
#       dtype=object)

# %%
df1 = df.copy()

# %%
df1[df1["year"]==2018]
# Out:
#        Unnamed: 0        Date  ...  year            region
# 8478            0  2018-03-25  ...  2018            Albany
# 8479            1  2018-03-18  ...  2018            Albany
# 8480            2  2018-03-11  ...  2018            Albany
# 8481            3  2018-03-04  ...  2018            Albany
# 8482            4  2018-02-25  ...  2018            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [1296 rows x 14 columns]

# %%
#1296 observations in 2018

# %%
df1[df1["year"]==2017]
# Out:
#        Unnamed: 0        Date  ...  year            region
# 5616            0  2017-12-31  ...  2017            Albany
# 5617            1  2017-12-24  ...  2017            Albany
# 5618            2  2017-12-17  ...  2017            Albany
# 5619            3  2017-12-10  ...  2017            Albany
# 5620            4  2017-12-03  ...  2017            Albany
# ...           ...         ...  ...   ...               ...
# 17596          46  2017-01-29  ...  2017  WestTexNewMexico
# 17597          47  2017-01-22  ...  2017  WestTexNewMexico
# 17598          48  2017-01-15  ...  2017  WestTexNewMexico
# 17599          49  2017-01-08  ...  2017  WestTexNewMexico
# 17600          50  2017-01-01  ...  2017  WestTexNewMexico
#
# [5722 rows x 14 columns]

# %%
#5722 observations in 2017

# %%
df1[df1["year"]==2016]
# Out:
#        Unnamed: 0        Date  ...  year            region
# 2808            0  2016-12-25  ...  2016            Albany
# 2809            1  2016-12-18  ...  2016            Albany
# 2810            2  2016-12-11  ...  2016            Albany
# 2811            3  2016-12-04  ...  2016            Albany
# 2812            4  2016-11-27  ...  2016            Albany
# ...           ...         ...  ...   ...               ...
# 14736          47  2016-01-31  ...  2016  WestTexNewMexico
# 14737          48  2016-01-24  ...  2016  WestTexNewMexico
# 14738          49  2016-01-17  ...  2016  WestTexNewMexico
# 14739          50  2016-01-10  ...  2016  WestTexNewMexico
# 14740          51  2016-01-03  ...  2016  WestTexNewMexico
#
# [5616 rows x 14 columns]

# %%
#5616 observations in 2016

# %%
df1[df1["year"]==2015]
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 11928          46  2015-02-01  ...  2015  WestTexNewMexico
# 11929          47  2015-01-25  ...  2015  WestTexNewMexico
# 11930          48  2015-01-18  ...  2015  WestTexNewMexico
# 11931          49  2015-01-11  ...  2015  WestTexNewMexico
# 11932          50  2015-01-04  ...  2015  WestTexNewMexico
#
# [5615 rows x 14 columns]

# %%
#5615 observations in 2015

# %%
df1[df1["year"]==2018].max()
# Out:
# Unnamed: 0                    11
# Date                  2018-03-25
# AveragePrice                 2.3
# Total Volume         6.25056e+07
# 4046                 2.16202e+07
# 4225                 2.04455e+07
# 4770                 1.06683e+06
# Total Bags           1.93731e+07
# Small Bags           1.33846e+07
# Large Bags            5.7191e+06
# XLarge Bags               309468
# type                     organic
# year                        2018
# region          WestTexNewMexico
# dtype: object

# %%
df1[df1["year"]==2017].max()
# Out:
# Unnamed: 0                    52
# Date                  2017-12-31
# AveragePrice                3.17
# Total Volume         6.10345e+07
# 4046                 2.27436e+07
# 4225                 2.03282e+07
# 4770                 1.66438e+06
# Total Bags           1.62983e+07
# Small Bags           1.25672e+07
# Large Bags           4.32423e+06
# XLarge Bags               377661
# type                     organic
# year                        2017
# region          WestTexNewMexico
# dtype: object

# %%
df1[df1["year"]==2016].max()
# Out:
# Unnamed: 0                    51
# Date                  2016-12-25
# AveragePrice                3.25
# Total Volume         5.22887e+07
# 4046                 1.65736e+07
# 4225                 2.04706e+07
# 4770                 2.54644e+06
# Total Bags           1.26981e+07
# Small Bags           9.96754e+06
# Large Bags           3.37308e+06
# XLarge Bags               551694
# type                     organic
# year                        2016
# region          WestTexNewMexico
# dtype: object

# %%
df1[df1["year"]==2015].max()
# Out:
# Unnamed: 0                    51
# Date                  2015-12-27
# AveragePrice                2.79
# Total Volume         4.46555e+07
# 4046                  1.8933e+07
# 4225                 1.89565e+07
# 4770                 1.61428e+06
# Total Bags           6.74361e+06
# Small Bags           5.89364e+06
# Large Bags           1.37144e+06
# XLarge Bags               199305
# type                     organic
# year                        2015
# region          WestTexNewMexico
# dtype: object

# %%
df1.describe()
# Out:
#          Unnamed: 0  AveragePrice  ...    XLarge Bags          year
# count  18249.000000  18249.000000  ...   18249.000000  18249.000000
# mean      24.232232      1.405978  ...    3106.426507   2016.147899
# std       15.481045      0.402677  ...   17692.894652      0.939938
# min        0.000000      0.440000  ...       0.000000   2015.000000
# 25%       10.000000      1.100000  ...       0.000000   2015.000000
# 50%       24.000000      1.370000  ...       0.000000   2016.000000
# 75%       38.000000      1.660000  ...     132.500000   2017.000000
# max       52.000000      3.250000  ...  551693.650000   2018.000000
#
# [8 rows x 11 columns]

# %%
df1.groupby("region")["region"].agg("count")
# Out:
# region
# Albany                 338
# Atlanta                338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# Midsouth               338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# ...

# %%
df2 = df1.copy()

# %%
df2.set_index("year", inplace = True)

# %%
df2.describe()
# Out:
#          Unnamed: 0  AveragePrice  ...    Large Bags    XLarge Bags
# count  18249.000000  18249.000000  ...  1.824900e+04   18249.000000
# mean      24.232232      1.405978  ...  5.433809e+04    3106.426507
# std       15.481045      0.402677  ...  2.439660e+05   17692.894652
# min        0.000000      0.440000  ...  0.000000e+00       0.000000
# 25%       10.000000      1.100000  ...  1.274700e+02       0.000000
# 50%       24.000000      1.370000  ...  2.647710e+03       0.000000
# 75%       38.000000      1.660000  ...  2.202925e+04     132.500000
# max       52.000000      3.250000  ...  5.719097e+06  551693.650000
#
# [8 rows x 10 columns]

# %%
df3 = df1.copy()

# %%
df3.groupby("year")

# %%
df2.drop("Date", axis = 1, inplace = True)

# %%
df2.drop("type", axis = 1, inplace=True)

# %%
df2.drop("region", axis = 1, inplace=True)
